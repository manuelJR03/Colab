# %% [markdown]
# <a href="https://colab.research.google.com/github/manuelJR03/Colab/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
dataset = pd.read_csv('smartphone_dataset_pt_br.csv')
dataset.head()
# Out:
#       Marca                     Modelo     Preço  Avaliação    5G    NFC  \
# 0   oneplus              OnePlus 11 5G  4915.665       89.0  True   True
# 1   oneplus  OnePlus Nord CE 2 Lite 5G  1786.560       81.0  True  False
# 2   samsung      Samsung Galaxy A14 5G  1474.635       75.0  True  False
# 3  motorola       Motorola Moto G62 5G  1340.565       81.0  True  False
# 4    realme         Realme 10 Pro Plus  2234.340       82.0  True  False
#
#    IR_Blaster Marca_Processador  Qtd_Cores  Veloc_Processador  ...  \
# 0       False        snapdragon        8.0                3.2  ...
# 1       False        snapdragon        8.0                2.2  ...
# 2       False            exynos        8.0                2.4  ...
# 3       False        snapdragon        8.0                2.2  ...
# 4       False         dimensity        8.0                2.6  ...
#
#    Tamanho_Tela  Taxa_Atualização     Resolução  Qtd_Câm_Tras  Qtd_Câm_Front  \
# ...

# %%
X = dataset.iloc[:, :-1].values
Y = dataset.iloc[:, 4].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20)
